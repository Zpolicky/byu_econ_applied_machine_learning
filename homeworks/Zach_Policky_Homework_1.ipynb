# %% [markdown]
# ## Data Cleaning, Describing, and Visualization
#
# ### Step 1 - Get your environment setup
#
# 1. Install Git on your computer and fork the class repository on [Github](https://github.com/tfolkman/byu_econ_applied_machine_learning).
# 2. Install [Anaconda](https://conda.io/docs/install/quick.html) and get it working.
#
# ### Step 2 - Explore Datasets
#
# The goals of this project are:
#
# 1. Read in data from multiple sources
# 2. Gain practice cleaning, describing, and visualizing data
#
# To this end, you need to find from three different sources. For example: CSV, JSON, and API, SQL, or web scraping. For each of these data sets, you must perform the following:
#
# 1. Data cleaning. Some options your might consider: handle missing data, handle outliers, scale the data, convert some data to categorical.
# 2. Describe data. Provide tables, statistics, and summaries of your data.
# 3. Visualize data. Provide visualizations of your data.
#
# These are the typical first steps of any data science project and are often the most time consuming. My hope is that in going through this process 3 different times, that you will gain a sense for it.
#
# Also, as you are doing this, please tell us a story. Explain in your notebook why are doing what you are doing and to what end. Telling a story in your analysis is a crucial skill for data scientists. There are almost an infinite amount of ways to analyze a data set; help us understand why you choose your particular path and why we should care.
#
# Also - this homework is very open-ended and we provided you with basically no starting point. I realize this increases the difficulty and complexity, but I think it is worth it. It is much closer to what you might experience in industry and allows you to find data that might excite you!

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data set 1: CSV - Crime data US cities

# %%
names = ['year_month', 'murder', 'rape', 'robbery', 'assault', 'burglary', 'larceny', 'vehicle_theft', 'population', 'city', 'ave_temp', 'prcp', 'snow']
crime = pd.read_csv("C:/Users/zachp/Dropbox/AAEcon/213r/crime_data.csv", header = None, names = names)
print(crime.head())

murd = crime['murder']
rape = crime['rape']
rob = crime['robbery']
assl = crime['assault']
burg = crime['burglary']
larc = crime['larceny']
veht = crime['vehicle_theft']
pop = crime['population']
city = crime['city']
# Out:
#    year_month    murder      rape   robbery   assault  burglary   larceny  \
# 0        7601  2.439098  3.949016  91.29195  212.4338  149.9465  287.8136
# 1        7602  2.322951  2.322951  71.54688  223.0033  124.5101  288.1620
# 2        7603  2.090656  4.645901  71.77917  233.9211  145.5329  315.2244
# 3        7604  1.626065  3.832868  63.99729  238.9155  125.9039  290.1365
# 4        7605  1.393770  4.645901  57.95761  262.1450  147.9720  326.0261
#
#    vehicle_theft  population           city  ave_temp      prcp      snow
# 0       63.18425    860974.0  Baltimore, MD  31.12903  0.132258  0.054839
# 1       46.80745    860974.0  Baltimore, MD  44.24138  0.074483  0.044828
# 2       48.20122    860974.0  Baltimore, MD  48.29032  0.071935  0.251613
# 3       46.92360    860974.0  Baltimore, MD  57.16667  0.042333  0.000000
# 4       64.22958    860974.0  Baltimore, MD  62.35484  0.162258  0.000000

# %%
#check for missing data
crime.isnull()
# Out:
#       year_month  murder   rape  robbery  assault  burglary  larceny  \
# 0          False   False  False    False    False     False    False
# 1          False   False  False    False    False     False    False
# 2          False   False  False    False    False     False    False
# 3          False   False  False    False    False     False    False
# 4          False   False  False    False    False     False    False
# 5          False   False  False    False    False     False    False
# 6          False   False  False    False    False     False    False
# 7          False   False  False    False    False     False    False
# 8          False   False  False    False    False     False    False
# 9          False   False  False    False    False     False    False
# 10         False   False  False    False    False     False    False
# 11         False   False  False    False    False     False    False
# 12         False   False  False    False    False     False    False
# ...

# %%
#since there doesnt seem to be a systematic missing of data we can just drop the missing values
crime1 = crime.dropna()
#Make a dataframe with the types of crimes I want to analyze
crime_df = crime1[['murder','rape', 'robbery', 'larceny', 'burglary', 'vehicle_theft']]

# %%
#describe the data
print('Full Data Set')
crime1.describe().round(2)
# Out:
# Full Data Set
#        year_month   murder     rape  robbery  assault  burglary  larceny  \
# count     3790.00  3790.00  3790.00  3790.00  3790.00   3790.00  3790.00
# mean      8649.58     1.83     5.75    54.04   127.58    167.83   345.72
# std        648.07     1.11     2.58    32.04    78.28     64.79   107.79
# min       7601.00     0.00     0.49     6.42    16.17     34.98    81.31
# 25%       8104.00     1.03     3.81    27.45    73.00    121.65   275.71
# 50%       8609.50     1.66     5.20    46.90   105.94    161.86   331.61
# 75%       9207.00     2.39     7.22    75.89   157.70    209.87   400.57
# max       9805.00     7.24    18.39   179.86   431.90    425.51   780.83
#
#        vehicle_theft  population  ave_temp     prcp     snow
# count        3790.00     3790.00   3790.00  3790.00  3790.00
# mean          102.71  1631137.54     61.19     0.09     0.03
# std            54.39  1727389.48     15.07     0.08     0.11
# ...

# %%
print('Crime_df')
crime_df.describe().round(2)
# Out:
# Crime_df
#         murder     rape  robbery  larceny  burglary  vehicle_theft
# count  3790.00  3790.00  3790.00  3790.00   3790.00        3790.00
# mean      1.83     5.75    54.04   345.72    167.83         102.71
# std       1.11     2.58    32.04   107.79     64.79          54.39
# min       0.00     0.49     6.42    81.31     34.98          11.80
# 25%       1.03     3.81    27.45   275.71    121.65          60.71
# 50%       1.66     5.20    46.90   331.61    161.86          92.59
# 75%       2.39     7.22    75.89   400.57    209.87         133.87
# max       7.24    18.39   179.86   780.83    425.51         356.11

# %%
#quick galnce at average values
pd.pivot_table(crime_df, index = [city], aggfunc = np.mean).round(2)
# Out:
#                    burglary  larceny  murder  rape  robbery  vehicle_theft
# city
# Baltimore, MD        166.99   388.82    2.82  6.41   100.86          87.01
# Chicago, IL           98.83   275.92    2.19  3.88    46.46          88.42
# Dallas, TX           239.40   517.56    2.60  8.53    55.84         119.36
# Detroit, MI          247.50   324.96    4.12  9.81   102.58         221.74
# Houston, TX          188.78   319.27    2.26  5.76    47.92         135.15
# Indianapolis, IN     153.66   282.03    1.41  7.71    36.94          76.53
# Jacksonville, FL     189.22   376.25    1.37  7.23    35.50          51.76
# Los Angeles, CA      157.33   290.21    2.07  5.53    69.64         125.50
# New York, NY         150.31   273.22    1.85  3.75    93.29         112.40
# Philadelphia, PA      97.40   197.02    1.91  4.23    53.61          93.37
# Phoenix, AZ          201.89   453.02    1.10  4.21    25.00          88.57
# ...

# %%
#I want to see which city has the worst murder rate
city_murder = crime.groupby(['city'])['murder'].mean()
city_murder.plot(kind = 'bar')
plt.ylabel('Murders')
plt.title("Average Murder Rates")

# %%
#also vehicle theft rate
veht = crime.groupby(['city'])['vehicle_theft'].mean()
veht.plot(kind = 'bar')
plt.title('Average City Vehicle Theft')

# %%
#seeing the correlations between variables is a quick way to visualize the data
crime_df.corr()
# Out:
#                  murder      rape   robbery   larceny  burglary  vehicle_theft
# murder         1.000000  0.510430  0.663215  0.165411  0.416488       0.637625
# rape           0.510430  1.000000  0.330163  0.336400  0.554782       0.356277
# robbery        0.663215  0.330163  1.000000  0.075326  0.253620       0.586601
# larceny        0.165411  0.336400  0.075326  1.000000  0.615597       0.179805
# burglary       0.416488  0.554782  0.253620  0.615597  1.000000       0.327131
# vehicle_theft  0.637625  0.356277  0.586601  0.179805  0.327131       1.000000

# %%
g = sns.PairGrid(crime_df)
g.map(plt.scatter);

# %% [markdown]
# Conclusions:
#
# Detroit has the highest crime rates as shown in the bar graphs. Also by looking at the scatter plots and correlation coefficients we can see that all types of crime are positively correlated in this data set.

# %% [markdown]
# # 2nd Data set: API key Macroeconomic variables

# %%
#import fredapi and use api key
from fredapi import Fred
fred = Fred(api_key="0ab84c0716dce20a131db35b9441f0ac")

# %%
#Real GDP
gdp = fred.get_series('GDPC1')
#Consumer Price Index as a measure of inflation
cpi = fred.get_series('CPIAUCNS')
#GDP deflator as an alternative measure of inflation
gdp_def = fred.get_series('GDPDEF')
#unemployment 
unemp = fred.get_series("UNRATENSA")

# %%
data = [gdp, cpi, gdp_def, unemp]
data_df = pd.concat(data, axis = 1)
data_df.columns = ['GDP', 'CPI', 'GDP_Def', 'Unemp']

# %%
#check for missing values
data_df.isnull()
# Out:
#               GDP    CPI  GDP_Def  Unemp
# 1913-01-01   True  False     True   True
# 1913-02-01   True  False     True   True
# 1913-03-01   True  False     True   True
# 1913-04-01   True  False     True   True
# 1913-05-01   True  False     True   True
# 1913-06-01   True  False     True   True
# 1913-07-01   True  False     True   True
# 1913-08-01   True  False     True   True
# 1913-09-01   True  False     True   True
# 1913-10-01   True  False     True   True
# 1913-11-01   True  False     True   True
# 1913-12-01   True  False     True   True
# 1914-01-01   True  False     True   True
# 1914-02-01   True  False     True   True
# 1914-03-01   True  False     True   True
# 1914-04-01   True  False     True   True
# 1914-05-01   True  False     True   True
# 1914-06-01   True  False     True   True
# 1914-07-01   True  False     True   True
# 1914-08-01   True  False     True   True
# 1914-09-01   True  False     True   True
# 1914-10-01   True  False     True   True
# ...

# %%
#It looks like each series has different periods of measurement and different starting dates
#We can drop the the missing rows since there isn't a systematic method for missing data

data_df2 = data_df.dropna()

# %%
data_df2.describe().round(2)
# Out:
#             GDP     CPI  GDP_Def   Unemp
# count    280.00  280.00   280.00  280.00
# mean    8088.18  107.01    53.49    5.82
# std     4656.62   74.80    33.42    1.70
# min     1989.54   23.50    13.38    2.40
# 25%     3986.22   31.55    18.71    4.70
# 50%     6649.29   98.00    52.69    5.55
# 75%    12596.32  171.68    81.76    7.00
# max    17272.47  246.66   114.28   11.40

# %%
#plot each series to see trends

data_df2["GDP"].plot()
plt.title("GDP")
plt.xlabel("Years")

# %%
data_df2['CPI'].plot()
plt.xlabel('Years')
plt.title('Consumer Price Index')

# %%
data_df2['GDP_Def'].plot()
plt.title('GDP Deflator')
plt.xlabel('Years')

# %%
data_df['Unemp'].plot()
plt.xlabel('Years')
plt.title('Unemployment')

# %%
u = data_df2['Unemp'].pct_change()
u.plot()
plt.title('% Change in Unemployment')
plt.xlabel('Years')

# %%
g = data_df2['GDP'].pct_change()
g.plot()
plt.title('% Change in GDP')
plt.xlabel('Years')

# %%
i = data_df2['CPI'].pct_change()
d = data_df2['GDP_Def'].pct_change()

#create a data frame with all the variables %change

change = [g,u,i,d]
change_df = pd.concat(change, axis = 1)
change_df.head()
# Out:
#                  GDP     Unemp       CPI   GDP_Def
# 1948-01-01       NaN       NaN       NaN       NaN
# 1948-04-01  0.016243  0.000000  0.004219  0.008820
# 1948-07-01  0.005591 -0.025000  0.025210  0.018523
# 1948-10-01  0.001069 -0.256410  0.000000  0.003055
# 1949-01-01 -0.013662  0.724138 -0.016393 -0.005222

# %%
correlation = sns.PairGrid(change_df)
correlation.map(plt.scatter);

# %%
change_df.corr()
# Out:
#               GDP     Unemp       CPI   GDP_Def
# GDP      1.000000 -0.227787 -0.068224 -0.062113
# Unemp   -0.227787  1.000000 -0.175518  0.035100
# CPI     -0.068224 -0.175518  1.000000  0.750104
# GDP_Def -0.062113  0.035100  0.750104  1.000000

# %% [markdown]
# Correlation Coefficients and Scatter plots tell us that increases in Unemployment and Inflation tend to yeild negative GDP change. Also increases in inflation when measured by the CPI tend to decrease Unemployment.

# %%
print("Variance in GDP")
sns.violinplot(data = gdp.pct_change(), color = 'red')
# Out:
# Variance in GDP

# %%
print('Variance in CPI')
sns.violinplot(data = cpi.pct_change())
# Out:
# Variance in CPI

# %%
print('Variance in GDP Deflator')
sns.violinplot(data = gdp_def.pct_change(), color = 'green')
# Out:
# Variance in GDP Deflator

# %%
print('Variance in Unemployment')
sns.violinplot(data = unemp.pct_change(), color = 'orange')
# Out:
# Variance in Unemployment

# %% [markdown]
# The Violin plots tell us that there is the largest variance in GDP and that all variables are single mode variables. This makes sense because GDP is a combination of lots of other moving variables.

# %% [markdown]
# # Data Set 3: DTA file Wages

# %%
#import data and look at it
wages = pd.read_stata("C:/Users/zachp/Dropbox/AAEcon/213r/WAGE2.dta")
wages.head()
# Out:
#     wage  hours     IQ   KWW  educ  exper  tenure   age  married  black  \
# 0  769.0   40.0   93.0  35.0  12.0   11.0     2.0  31.0      1.0    0.0
# 1  808.0   50.0  119.0  41.0  18.0   11.0    16.0  37.0      1.0    0.0
# 2  825.0   40.0  108.0  46.0  14.0   11.0     9.0  33.0      1.0    0.0
# 3  650.0   40.0   96.0  32.0  12.0   13.0     7.0  32.0      1.0    0.0
# 4  562.0   40.0   74.0  27.0  11.0   14.0     5.0  34.0      1.0    0.0
#
#    south  urban  sibs  brthord  meduc  feduc     lwage
# 0    0.0    1.0   1.0      2.0    8.0    8.0  6.645091
# 1    0.0    1.0   1.0      NaN   14.0   14.0  6.694562
# 2    0.0    1.0   1.0      2.0   14.0   14.0  6.715384
# 3    0.0    1.0   4.0      3.0   12.0   12.0  6.476973
# 4    0.0    1.0  10.0      6.0    6.0   11.0  6.331502

# %%
#check for missing variables
wages.isnull()
# Out:
#       wage  hours     IQ    KWW   educ  exper  tenure    age  married  black  \
# 0    False  False  False  False  False  False   False  False    False  False
# 1    False  False  False  False  False  False   False  False    False  False
# 2    False  False  False  False  False  False   False  False    False  False
# 3    False  False  False  False  False  False   False  False    False  False
# 4    False  False  False  False  False  False   False  False    False  False
# 5    False  False  False  False  False  False   False  False    False  False
# 6    False  False  False  False  False  False   False  False    False  False
# 7    False  False  False  False  False  False   False  False    False  False
# 8    False  False  False  False  False  False   False  False    False  False
# 9    False  False  False  False  False  False   False  False    False  False
# 10   False  False  False  False  False  False   False  False    False  False
# ...

# %%
#seeing very few missing variables and a large sample size we can drop the rows with missing variables. 
#then we can check for outlyers in the variables of interest. Wage, hours, education

wage = wages.dropna()
wage['wage'].plot(kind = 'box')
plt.title('Wages Box Plot')
#we can see that there are outlyers in wage

# %%
print(wage['wage'].max())
std_wage = wage['wage'].std()
print(wage['wage'].mean()+(std_wage*3))
# Out:
# 3078.0
# 2208.0098876953125

# %%
#wage max is much larger than 3 times the standard deviation of wages

# %%
wage['hours'].plot(kind='box')
plt.title('Hours Box Plot')
#we can see there there are outlyers in hours 
print(wage['hours'].max())
std_hours = wage['hours'].std()
print(wage['hours'].mean()+(std_hours*3))
# Out:
# 80.0
# 65.5413990020752

# %%
wage['educ'].plot(kind='box')
plt.title('Education Box Plot')
print(wage['educ'].max())
std_educ = wage['educ'].std()
print(wage['educ'].mean()+(std_educ*3))
#not a huge difference between max and 3 times std
# Out:
# 18.0
# 20.374465942382812

# %%
#hours max is also larger than 3 times the standard deviation of wages so we can drop the outlyers above
wage_df = wage[(wage['wage']<2209) & (wage['hours']<66)]

print(wage.count())
print(wage_df.count())
# Out:
# wage       663
# hours      663
# IQ         663
# KWW        663
# educ       663
# exper      663
# tenure     663
# age        663
# married    663
# black      663
# south      663
# urban      663
# sibs       663
# brthord    663
# meduc      663
# feduc      663
# lwage      663
# dtype: int64
# wage       647
# hours      647
# IQ         647
# KWW        647
# educ       647
# exper      647
# tenure     647
# age        647
# married    647
# black      647
# south      647
# urban      647
# sibs       647
# brthord    647
# meduc      647
# feduc      647
# lwage      647
# dtype: int64

# %%
#find the number of observations dropped

print(663-647)
# Out:
# 16

# %%
#now there are less outliers
wage_df['wage'].plot(kind = 'box')

# %%
wage_df.describe()
# Out:
#               wage       hours          IQ         KWW        educ  \
# count   647.000000  647.000000  647.000000  647.000000  647.000000
# mean    972.982971   43.636784  102.527046   36.142193   13.670788
# std     367.575012    6.266490   14.646363    7.496638    2.232907
# min     115.000000   25.000000   54.000000   13.000000    9.000000
# 25%     700.000000   40.000000   94.000000   32.000000   12.000000
# 50%     937.000000   40.000000  104.000000   37.000000   13.000000
# 75%    1200.000000   46.500000  113.000000   41.000000   16.000000
# max    2162.000000   65.000000  145.000000   56.000000   18.000000
#
#             exper      tenure         age     married       black       south  \
# count  647.000000  647.000000  647.000000  647.000000  647.000000  647.000000
# mean    11.440495    7.279753   32.969090    0.899536    0.083462    0.324575
# std      4.234873    5.063431    3.059115    0.300851    0.276793    0.468578
# ...

# %%
pd.pivot_table(wage_df, values='wage', index= ['sibs','brthord'], aggfunc =np.mean).round(2)
# Out:
#                      wage
# sibs brthord
# 0.0  1.0      1049.400024
# 1.0  1.0      1071.839966
#      2.0       992.909973
# 2.0  1.0      1070.430054
#      2.0       941.760010
#      3.0       976.940002
# 3.0  1.0      1060.479980
#      2.0       941.320007
#      3.0       972.830017
#      4.0       914.520020
# 4.0  1.0       871.929993
#      2.0       881.469971
#      3.0       873.000000
#      4.0       812.109985
#      5.0       840.780029
# 5.0  1.0       990.309998
#      2.0       855.429993
#      3.0       906.380005
#      4.0       925.250000
#      5.0       813.429993
#      6.0       559.000000
# 6.0  1.0       865.549988
#      2.0       825.000000
#      3.0       828.599976
#      4.0       688.000000
#      5.0       914.500000
#      6.0       858.000000
#      7.0      1126.000000
# 7.0  1.0      1166.329956
#      2.0       797.669983
#      3.0      1040.250000
#      5.0       981.000000
#      6.0       780.669983
#      7.0       779.599976
# ...

# %%
#a quick glance at the tables shows that oldest siblings typically make more money than younger siblings with the same amount of education. 
#now that the data is clean we can start to look at correlations 
w_df = wage_df[['wage', 'hours', 'educ','sibs', 'brthord', 'age']]
w_df.corr()
# Out:
#              wage     hours      educ      sibs   brthord       age
# wage     1.000000 -0.037860  0.346025 -0.159635 -0.174574  0.178798
# hours   -0.037860  1.000000  0.101407 -0.040033 -0.081002  0.010961
# educ     0.346025  0.101407  1.000000 -0.205307 -0.177321  0.035447
# sibs    -0.159635 -0.040033 -0.205307  1.000000  0.583291 -0.067752
# brthord -0.174574 -0.081002 -0.177321  0.583291  1.000000 -0.044061
# age      0.178798  0.010961  0.035447 -0.067752 -0.044061  1.000000

# %%
#according to the correlation coefficients wages negatively impacted by number of siblings and by birth order
#now we should look at the scatter plots
w = sns.PairGrid(w_df)
w.map(plt.scatter);

# %%
#the scatter plots show the correlation bewtween wages and sibling number and birthorder is negative
